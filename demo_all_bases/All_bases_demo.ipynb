# %%
import pandas as pd

# %% [markdown]
# ## ОБД (донесения о потерях)

# %%
obd_losses = pd.read_json('obd_chelovek_donesenie_sample.jsonl', lines=True)
obd_losses.head()
# Out:
#                                 data_i_mesto_priziva  \
# 0
# 1
# 2  Карагандинский РВК, Казахская ССР, Карагандинс...
# 3  Боготольский РВК, Красноярский край, Боготольс...
# 4
#
#                 data_i_pervichnoe_mesto_zahoroneniya data_vibitiya  \
# 0  Смоленская обл., Всходский р-н, с. Большое Зах...    11.08.1941
# 1    Смоленская обл., Кировский р-н, д. Новое Мутище    08.08.1941
# 2    Смоленская обл., Кировский р-н, д. Новое Мутище    08.08.1941
# 3                                                       11.08.1941
# 4                                                       11.08.1941
#
#     birthdate                                   documents_pages dolgota  \
# 0  __.__.1912  {:documents_id=>[1000004], :pages_id=>[1000006]}
# 1  __.__.1916  {:documents_id=>[1000004], :pages_id=>[1000006]}
# 2  __.__.1916  {:documents_id=>[1000004], :pages_id=>[1000006]}
# 3  __.__.1917  {:documents_id=>[1000004], :pages_id=>[1000006]}
# ...

# %%
obd_losses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 39 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   data_i_mesto_priziva                  10 non-null     object
#  1   data_i_pervichnoe_mesto_zahoroneniya  10 non-null     object
#  2   data_vibitiya                         10 non-null     object
#  3   birthdate                             10 non-null     object
#  4   documents_pages                       10 non-null     object
#  5   dolgota                               10 non-null     object
#  6   dolgota_raitsentra                    10 non-null     object
#  7   dop_informatsiya                      10 non-null     object
#  8   entity                                10 non-null     object
#  9   firstname                             10 non-null     object
#  10  fulltextfield                         10 non-null     object
# ...

# %% [markdown]
# ## Блокадники:

# %%
blokada = pd.read_json('blokada_sample.jsonl', lines=True)
blokada.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/json/_json.py:1026: UserWarning: Parsing '17.03.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   new_data = to_datetime(new_data, errors="raise", unit=date_unit)
#                        fullname   birthdate  firstname     patronym   surname  \
# 0     Хоникова Юлия Терентьевна  05.12.1930       Юлия  Терентьевна  Хоникова
# 1  Иванова Валентина Михайловна  20.01.1921  Валентина   Михайловна   Иванова
# 2       Козлова Нина Алексеевна  07.01.1926       Нина   Алексеевна   Козлова
#
#                     place_of_residence death_date burial_place  \
# 0  г. Санкт-Петербург, Калининский р-н
# 1                        Кировский р-н
# 2                       Выборгский р-н
#
#                         source       id retrieved_at  \
# 0  Они пережили Блокаду, т. 13  1919776   2021-03-17
# 1   Они пережили Блокаду, т. 4  1955406   2021-03-17
# ...

# %%
blokada.info()

# %% [markdown]
# ## Партизаны:

# %%
partisans = pd.read_json('partisans_sample.jsonl', lines=True)

# %%
partisans.head()
# Out:
#                                  original_link retrieved_at     surname  \
# 0  https://partizany.by/partisans/110588.html/   2021-06-20  Альшевская
# 1   https://partizany.by/partisans/51428.html/   2021-06-20     Ермолов
# 2  https://partizany.by/partisans/115270.html/   2021-06-20     Вареник
# 3  https://partizany.by/partisans/143410.html/   2021-06-20   Томашевич
# 4   https://partizany.by/partisans/65874.html/   2021-06-20  Зеленкевич
#
#    firstname     patronym  birthdate  \
# 0  Анастасия   Васильевна       1915
# 1       Иван     Ефимович       1909
# 2  Александр     Язепович       1912
# 3  Валентина    Федоровна       1929
# 4     Прокоф  Евдокимович       1914
#
#                                           birthplace nationality  \
# 0  д.Стрикели, Полоцкий р-н, Витебская область, БССР     Белорус
# 1  д.Староложниково, Городищенский р-н, Новосибир...     Русский
# 2   д. Старина, Руденский р-н, Минская область, БССР     Белорус
# ...

# %%
partisans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   original_link        81 non-null     object
#  1   retrieved_at         81 non-null     datetime64[ns]
#  2   surname              81 non-null     object
#  3   firstname            81 non-null     object
#  4   patronym             81 non-null     object
#  5   birthdate            81 non-null     int64
#  6   birthplace           81 non-null     object
#  7   nationality          81 non-null     object
#  8   award                81 non-null     object
#  9   award_nomination     81 non-null     object
#  10  time_period          81 non-null     object
#  11  partisan_brigade     81 non-null     object
#  12  partisan_detachment  81 non-null     object
#  13  position             81 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(12)
# ...

# %% [markdown]
# ## Новомученики

# %%
martyrs = pd.read_json('martyrs_sample.jsonl', lines=True)
martyrs.head()
# Out:
#    person_id                                    full_name  \
# 0       1375      {'name': 'Сергий', 'surname': 'Аманов'}
# 1        340     {'name': 'Виктор', 'surname': 'Киранов'}
# 2        710    {'name': 'Михаил', 'surname': 'Люберцев'}
# 3        205   {'name': 'Василий', 'surname': 'Надеждин'}
# 4        985  {'name': 'Николай', 'surname': 'Верещагин'}
#
#                                               source     relig_status  \
# 0  {'publication': '«Жития новомучеников и испове...  Священномученик
# 1  {'publication': '«Жития новомучеников и испове...  Священномученик
# 2  {'publication': '«Мученики, исповедники и подв...  Священномученик
# 3  {'publication': '«Жития новомучеников и испове...  Священномученик
# 4  {'publication': '«Мученики, исповедники и подв...  Священномученик
#
#    occupation birth_place                              birth_date  \
# 0   священник     Касимов  {'day': 10, 'month': 12, 'year': None}
# ...

# %%
martyrs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   person_id      5 non-null      int64
#  1   full_name      5 non-null      object
#  2   source         5 non-null      object
#  3   relig_status   5 non-null      object
#  4   occupation     5 non-null      object
#  5   birth_place    5 non-null      object
#  6   birth_date     5 non-null      object
#  7   death_date     5 non-null      object
#  8   original_text  5 non-null      object
#  9   original_url   5 non-null      object
# dtypes: int64(1), object(9)
# memory usage: 528.0+ bytes

# %% [markdown]
# ## ПСТГУ (православное духовенство)

# %%
pstgu = pd.read_json('pstgu_sample.jsonl', lines=True)
pstgu.head()
# Out:
#        ID                            ФИО Дата рождения Дата смерти  \
# 0  106662     АБРАМОВА Мария Кузьминична    неизвестно  неизвестно
# 1  106663                  АБРАМОВА Нина    неизвестно  неизвестно
# 2  106664    АБРАМОВА Пелагея Дмитриевна          1880  неизвестно
# 3  106665     АБРАМОВА Пелагея Никитична          1892  неизвестно
# 4  106666  АБРАМОВА Прасковья Васильевна          1882  28.10.1940
#
#                  Память       Сан  \
# 0  25 января, 8 февраля  монахиня
# 1  25 января, 8 февраля  монахиня
# 2  25 января, 8 февраля  монахиня
# 3  25 января, 8 февраля  монахиня
# 4  25 января, 8 февраля  монахиня
#
#                                            Биография  \
# 0  1934 — Арестована в г. Выксе Горьковского края...
# 1  1920 — Арестована в с. Белбаш Ковернинского уе...
# 2  1880 — Год рождения. Проживала в г. Ардатове Н...
# 3  1892 — Родилась в с. Грязное Задноского уезда ...
# 4  1882 — Родилась в с. Карсаевка Чембарского уез...
#
# ...

# %%
pstgu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  5 non-null      int64
#  1   ФИО                 5 non-null      object
#  2   Дата рождения       5 non-null      object
#  3   Дата смерти         5 non-null      object
#  4   Память              5 non-null      object
#  5   Сан                 5 non-null      object
#  6   Биография           5 non-null      object
#  7   Публикации          5 non-null      object
#  8   Архивные источники  5 non-null      object
#  9   Заявители           5 non-null      object
# dtypes: int64(1), object(9)
# memory usage: 528.0+ bytes

# %% [markdown]
# ### Востоковеды

# %%
vostok = pd.read_json('vostokovedy_sample.jsonl', lines=True)
vostok.head()
# Out:
#        surname   firstname     patronym                         fullname  \
# 0      Блюмкин        Яков  Григорьевич         Блюмкин Яков Григорьевич
# 1      Бобкова       Ольга   Дмитриевна         Бобкова Ольга Дмитриевна
# 2  Боданинский       Усеин  Абдрефиевич    Боданинский Усеин Абдрефиевич
# 3      Болодон    Базаржаб  Болодонович     Болодон Базаржаб Болодонович
# 4     Болтенко  Константин  Григорьевич  Болтенко Константин Григорьевич
#
#     gender  birthdate                         birthplace death_date  \
# 0  мужчина       1900
# 1  женщина       1900         Калужский у. Калужской губ
# 2  мужчина       1877       д. Бадана Симферопольского у       1938
# 3  мужчина       1906  Могойтуй Агинского аймака Бурятии       1937
# 4  мужчина       1911  м. Еленовка Екатеринославской губ
#
#                                     original_link retrieved_at
# 0      http://memory.pvost.org/pages/blumkin.html   2021-05-18
# ...

# %%
vostok.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   surname        5 non-null      object
#  1   firstname      5 non-null      object
#  2   patronym       5 non-null      object
#  3   fullname       5 non-null      object
#  4   gender         5 non-null      object
#  5   birthdate      5 non-null      int64
#  6   birthplace     5 non-null      object
#  7   death_date     5 non-null      object
#  8   original_link  5 non-null      object
#  9   retrieved_at   5 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 528.0+ bytes
