# %% [markdown]
# # Валидатор

# %%
# !python3 -m app.converter                    \
  --input Partisans_upd.json                      \
  --input-type json-array       \
  --output database_corrected.json.gz        \
  --mapping database_mapping.tsv             \
  --validation db_fields.tsv                 \
  --validation-mode ignore   \
  --validation-formatting full
# Out:
# Traceback (most recent call last):
#   File "/opt/miniconda3/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/opt/miniconda3/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/Users/annalevina/biographies_webface/app/converter/__main__.py", line 72, in <module>
#     main()
#   File "/Users/annalevina/biographies_webface/app/converter/__main__.py", line 64, in main
#     for line in input_stream:
#   File "/Users/annalevina/biographies_webface/app/converter/__main__.py", line 18, in filter_records
#     for record in records:
#   File "/Users/annalevina/biographies_webface/app/converter/transformation.py", line 9, in __call__
#     for k,v in record.items():
# AttributeError: 'str' object has no attribute 'items'

# %%
import pandas as pd

# %%
df = df = pd.read_json('Partisans_upd.json')
print(df)
# Out:
#                                       original_link retrieved_at     surname  \
# 0       https://partizany.by/partisans/110588.html/   2021-06-20  Альшевская
# 1        https://partizany.by/partisans/51428.html/   2021-06-20     Ермолов
# 2       https://partizany.by/partisans/115270.html/   2021-06-20     Вареник
# 3       https://partizany.by/partisans/143410.html/   2021-06-20   Томашевич
# 4        https://partizany.by/partisans/65874.html/   2021-06-20  Зеленкевич
# ...                                             ...          ...         ...
# 144666   https://partizany.by/partisans/30790.html/   2021-06-20   Царенкова
# 144667  https://partizany.by/partisans/127050.html/   2021-06-20   Данилевич
# 144668   https://partizany.by/partisans/35068.html/   2021-06-20      Пачкай
# 144669   https://partizany.by/partisans/63608.html/   2021-06-20       Бегун
# 144670   https://partizany.by/partisans/48558.html/   2021-06-20   Рафальчик
#
# ...
